# %%
cecl_pdf = r"D:\Daaslabs\PCBB_FIT\raw_files\Sample\Reporting_CECL.pdf"

import PyPDF2

# creating a pdf reader object
reader = PyPDF2.PdfReader(cecl_pdf)

# print the number of pages in pdf file
print(len(reader.pages))

# print the text of the first page
print(reader.pages[0].extract_text())

print(reader.pages[1].extract_text())
# Out:
# 1621
# Home Screen ?
# CECL FIT
# Expertise and Guidance that go beyond Software
# TM
# Generated as of 6/27/23. Proprietary and Confidential.PENTUCKET BANKAs of 3/31/2023
# Executive ?
# Current Estimated Credit Losses Summary
# As of 3/31/2023
# Group Methodology Balance Est Life Reserve % Reserve $
# Construction & Land
# Multifamily
# Single Family Sr Lien
# Single Family Jr Lien
# Single Family HELOC
# Farmland
# Agriculture
# Commercial & Industrial
# Consumer
# Commercial Real Estate: Construction
# & Land
# Multifamily: Construction & Land
# Collateral Dependent: Commercial &
# Industrial
# Collateral Dependent: Commercial Real
# Estate
# Government Guaranteed - 50%:
# Commercial & Industrial
# Government Guaranteed - 75%:
# Commercial & Industrial
# Government Guaranteed - 75%:
# Commercial Real Estate
# Government Guaranteed - 85%:
# Commercial & Industrial
# Non-Owner Occupied: Commercial
# Real Estate
# Owner Occupied: Commercial Real
# EstateAvg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off
# Avg Charge-Off12,733,082 22.1 2.22% 283,168
# 38,245,924 76.8 0.86% 327,860
# 366,739,202 69.9 0.54% 1,964,256
# 6,784,869 35.1 1.91% 129,549
# 20,782,641 64.7 0.94% 194,542
# 207,177 45.3 0.87% 1,801
# 165,030 10.3 0.28% 461
# 39,955,922 27.1 1.50% 598,393
# 3,448,967 27.4 1.51% 52,155
# 11,874,699 41.0 1.66% 197,367
# 3,186,790 64.9 0.75% 24,021
# 66,055 8.8 0.00% 0
# 442,605 32.8 0.00% 0
# 29,401 26.5 1.05% 310
# 3,803,641 30.4 1.00% 38,046
# 403,569 42.6 0.64% 2,571
# 24,056 10.3 0.39% 95
# 132,598,415 48.6 0.99% 1,317,538
# 101,862,505 50.5 1.03% 1,051,029Loans
